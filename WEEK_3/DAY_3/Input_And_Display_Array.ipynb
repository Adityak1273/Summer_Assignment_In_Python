# %% [markdown]
# Input and dispaly array

# %%
n=int(input("Enter the number of elements of an array : "))
list=[]
for i in range(0,n):
    n1=int(input("Enter the elements of an array : "))
    list.append(n1)         
print("Array of input number : ",list)
# Out:
# Array of input number :  [5, 7]
