# %% [markdown]
# Linear search

# %%
n=int(input("Enter the total number of elements, you want to enter : "))
list=[]
count=0
for i in range(1,n+1):
    n1=int(input("Enter elements : "))
    list.append(n1)
n2=int(input("Enter the number , you want to find location of :"))
print("Location of ",n2," in array are : ",end="")
for i in list:
    if i==n2:
        print(count)
    count+=1
# Out:
# Location of  3  in array are : 2
# 3
