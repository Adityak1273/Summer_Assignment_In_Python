# %% [markdown]
# Second largest element

# %%
n=int(input("Enter the total number of elements, you want to enter : "))
list=[]
list_1=[]
count=0
for i in range(1,n+1):
    n1=int(input("Enter elements : "))
    list.append(n1)
large=0
for i in list:
    if large<i:
        large=i
for i in list:
    if large!=i:
        list_1.append(i)
large=0
for i in list_1:
    if large<i:
        large=i
print("Second largest element of array ",list," are : ",large)
# Out:
# Second largest element of array  [1, 2, 3, 4, 4, 5]  are :  4
