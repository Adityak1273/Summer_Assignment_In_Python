# %% [markdown]
# Rotate array right

# %%
n=int(input("Enter the total number of elements, you want to enter : "))
list=[]
list_1=[]
n2=0
for i in range(1,n+1):
    n1=int(input("Enter elements : "))
    list.append(n1)
list_1=list.copy()
print("The process of shifting, each step : ",end="")
for i in range(n-1,-1,-1):
    print(list)
    n2=list_1[i]
    list.remove(n2)
    list.insert(n-i-1,n2)
print("Final output : ",list)
# Out:
# The process of shifting, each step : [1, 2, 3, 4]
# [4, 1, 2, 3]
# [4, 3, 1, 2]
# [4, 3, 2, 1]
# Final output :  [4, 3, 2, 1]
