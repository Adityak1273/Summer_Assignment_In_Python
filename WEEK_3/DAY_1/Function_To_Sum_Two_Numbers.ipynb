# %% [markdown]
# Function to find sum of two numbers

# %%
def sum(n1,n2):
    return n1+n2
n1=int(input("Enter the first number : "))
n2=int(input("Enter the second number : "))
print("Sum of the numbers",n1,"and",n2,"are :",sum(n1,n2))
# Out:
# Sum of the numbers 5 and 4 are : 9
