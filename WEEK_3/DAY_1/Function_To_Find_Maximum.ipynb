# %% [markdown]
# Function to find sum of two numbers

# %%
def max(n1,n2):
    if n1>n2:
        print("Maximun number : ",end="")
        return n1
    elif n1<n2:
        print("Maximun number : ",end="")
        return n2
    else:
        return "Equal"
n1=int(input("Enter the first number : "))
n2=int(input("Enter the first number : ")) 
print(max(n1,n2))
# Out:
# Equal
