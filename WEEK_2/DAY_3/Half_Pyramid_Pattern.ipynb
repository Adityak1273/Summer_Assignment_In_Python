# %% [markdown]
# Half pyramid pattern
# *
# **
# ***
# ****
# and so on ....

# %%
n=int(input("Enter the pyramid layer : "))
for i in range(1,n+1):
    for j in range(0,i):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
