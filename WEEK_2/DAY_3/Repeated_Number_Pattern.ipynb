# %% [markdown]
# repeated number pattern
# 1
# 22
# 333
# 4444
# and so on ....

# %%
n=int(input("Enter the pyramid layer : "))
for i in range(1,n+1):
    for j in range(1,i+1):
        print(i,end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555
