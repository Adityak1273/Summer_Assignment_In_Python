# %% [markdown]
# Reverse star pattern
# *****
# ****
# ***
# **
# *

# %%
n=int(input("Enter the pyramid layer : "))
for i in range(n,0,-1):
    for j in range(i):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *
