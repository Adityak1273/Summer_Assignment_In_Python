# %% [markdown]
# Reverse number triangle
# 12345
# 1234
# 123
# 12
# 1
# and so on ....

# %%
n=int(input("Enter the pyramid layer : "))
for i in range(n+1,1,-1):
    for j in range(1,i):
        print(j,end="")
    print()
# Out:
# 12345
# 1234
# 123
# 12
# 1
