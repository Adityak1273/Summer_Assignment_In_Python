# %% [markdown]
# Star pyramid
#     *
#    ***
#   *****
#  *******
# *********

# %%
n=int(input("Enter the layers of pyramid : "))
add=1
n1=n
for i in range(n,0,-1):
    for j in range(1,i):
        print(" ",end="")
    for k in range(0,1+(add-1)*2):
        print("*",end="")
    if add<n:
        add+=1
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********
