# %% [markdown]
# Maximum frequency element

# %%
n=int(input("Enter the total number of elements, you want to enter : "))
list=[]
list_1=[]
list_2=[]
for i in range(1,n+1):
    n1=int(input("Enter elements : "))
    list.append(n1)
num1=len(list)
for i in range(0,num1):
    count=0
    for j in range(i+1,num1):
        if list[i]==list[j]:
            count+=1
    list_1.append(list[i])
    list_2.append(list[j])
    list.pop(i)
count=0
count_1=0
for i in list_2:
    if count_1<i:
        count_1=i
        count_2=count
    count+=1
print("Maximum frequency element ",list_1[count_2]," of frequency : ",list_2[count_2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 12
#       8 num1=len(list)
#       9 for i in range(0,num1):
#      10     count=0
#      11     for j in range(i+1,num1):
# ---> 12         num_1=list[i].copy
#      13         num_2=list[j].copy
#      14         if num_1==num_2:
#      15             count+=1
#
# AttributeError: 'int' object has no attribute 'copy'
